# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\James\Downloads\Student Mental health.csv')
df
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
#split column 'Timestamp' in to 2 column 'date' and 'time' and put in front
df['Dates'] = pd.to_datetime(df['Timestamp']).dt.date
df['Time'] = pd.to_datetime(df['Timestamp']).dt.time
first =  df.pop('Dates')
df.insert(0, 'Dates', first)
second = df.pop("Time")
df.insert(1, 'Time', second)

# Then drop column 'Timestamp'
df = df.drop(['Timestamp'], axis=1)
df.head()
# Out:
#         Dates      Time Choose your gender   Age What is your course?  \
# 0  2020-08-07  12:02:00             Female  18.0          Engineering
# 1  2020-08-07  12:04:00               Male  21.0    Islamic education
# 2  2020-08-07  12:05:00               Male  19.0                  BIT
# 3  2020-08-07  12:06:00             Female  22.0                 Laws
# 4  2020-08-07  12:13:00               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 12 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Dates                                         101 non-null    object
#  1   Time                                          101 non-null    object
#  2   Choose your gender                            101 non-null    object
#  3   Age                                           100 non-null    float64
#  4   What is your course?                          101 non-null    object
#  5   Your current year of Study                    101 non-null    object
#  6   What is your CGPA?                            101 non-null    object
#  7   Marital status                                101 non-null    object
#  8   Do you have Depression?                       101 non-null    object
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Age                                             1
# Dates                                           0
# Time                                            0
# Choose your gender                              0
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %%
#replace missing value
df[df['Age'].isna()]
df['Age']=df['Age'].replace(np.nan,19)
df.head(44)
# Out:
#          Dates      Time Choose your gender   Age     What is your course?  \
# 0   2020-08-07  12:02:00             Female  18.0              Engineering
# 1   2020-08-07  12:04:00               Male  21.0        Islamic education
# 2   2020-08-07  12:05:00               Male  19.0                      BIT
# 3   2020-08-07  12:06:00             Female  22.0                     Laws
# 4   2020-08-07  12:13:00               Male  23.0             Mathemathics
# 5   2020-08-07  12:31:00               Male  19.0              Engineering
# 6   2020-08-07  12:32:00             Female  23.0         Pendidikan islam
# 7   2020-08-07  12:33:00             Female  18.0                      BCS
# 8   2020-08-07  12:35:00             Female  19.0          Human Resources
# 9   2020-08-07  12:39:00               Male  18.0                    Irkhs
# 10  2020-08-07  12:39:00             Female  20.0               Psychology
# ...

# %%
for i in df.columns:
    print(df[i].unique())
# Out:
# [datetime.date(2020, 8, 7) datetime.date(2020, 9, 7)
#  datetime.date(2020, 7, 13) datetime.date(2020, 7, 18)]
# [datetime.time(12, 2) datetime.time(12, 4) datetime.time(12, 5)
#  datetime.time(12, 6) datetime.time(12, 13) datetime.time(12, 31)
#  datetime.time(12, 32) datetime.time(12, 33) datetime.time(12, 35)
#  datetime.time(12, 39) datetime.time(12, 40) datetime.time(12, 41)
#  datetime.time(12, 43) datetime.time(12, 46) datetime.time(12, 52)
#  datetime.time(13, 5) datetime.time(13, 7) datetime.time(13, 12)
#  datetime.time(13, 13) datetime.time(13, 15) datetime.time(13, 17)
#  datetime.time(13, 29) datetime.time(13, 35) datetime.time(13, 41)
#  datetime.time(13, 58) datetime.time(14, 5) datetime.time(14, 27)
#  datetime.time(14, 29) datetime.time(14, 31) datetime.time(14, 41)
#  datetime.time(14, 43) datetime.time(14, 45) datetime.time(14, 47)
#  datetime.time(14, 56) datetime.time(14, 57) datetime.time(14, 58)
#  datetime.time(15, 7) datetime.time(15, 8) datetime.time(15, 9)
# ...

# %%
#Cleaning the data
#Take out unnessesary space.
df['What is your course?'] = df['What is your course?'].str.rstrip()

# %%
# Capitalize worlds
df['What is your course?'] = df['What is your course?'].str.capitalize()
df['Your current year of Study'] = df['Your current year of Study'].str.capitalize()

# %%
#Replace the repeat value 
#Replace the repeat value 
df['What is your course?']=df['What is your course?'].replace('Law','Laws')
df['What is your course?']=df['What is your course?'].replace('Pendidikan islam','Islamic education')
df['What is your course?']=df['What is your course?'].replace('Usuluddin','Islamic education')
df['What is your course?']=df['What is your course?'].replace('FIQH','Islamic education')
df['What is your course?']=df['What is your course?'].replace('Fiqh fatwa','Islamic education')
df['What is your course?']=df['What is your course?'].replace('Fiqh','Islamic education')
df['What is your course?']=df['What is your course?'].replace('Kirkhs','Islamic education')
df['What is your course?']=df['What is your course?'].replace('Irkhs','Islamic education')
df['What is your course?']=df['What is your course?'].replace('engin','Engineering')
df['What is your course?']=df['What is your course?'].replace('Engine','Engineering')
df['What is your course?']=df['What is your course?'].replace('Diploma nursing','Nursing')
df['What is your course?']=df['What is your course?'].replace('Nursing','Nursing')
df['What is your course?']=df['What is your course?'].replace('Enm','Laws')
df['What is your course?']=df['What is your course?'].replace('Bcs','It')
df['What is your course?']=df['What is your course?'].replace('Bit','It')
df['What is your course?']=df['What is your course?'].replace('Koe','Engineering')
df['What is your course?']=df['What is your course?'].replace('Kop','Phamacy')
df['What is your course?']=df['What is your course?'].replace('Benl','English')
df['What is your course?']=df['What is your course?'].replace('Diploma tesl','English')
df['What is your course?']=df['What is your course?'].replace('Econs','Economics')
df['What is your course?']=df['What is your course?'].replace('Mhsc','Master Health Science')
df['What is your course?']=df['What is your course?'].replace('Malcom','Communication Machine learning')
df['What is your course?']=df['What is your course?'].replace('Kenms','Economics')
df['What is your course?']=df['What is your course?'].replace('Taasl','It')

# %%
df['What is your CGPA?']= df['What is your CGPA?'].replace('3.50 - 4.00 ','3.50 - 4.00')
df['What is your CGPA?']= df['What is your CGPA?'].replace('0 - 1.99', 1)
df['What is your CGPA?']= df['What is your CGPA?'].replace('2.00 - 2.49', 2)
df['What is your CGPA?']= df['What is your CGPA?'].replace('2.50 - 2.99', 3)
df['What is your CGPA?']= df['What is your CGPA?'].replace('3.00 - 3.49', 3)
df['What is your CGPA?']= df['What is your CGPA?'].replace('3.50 - 4.00', 4)

# %%
# Capitalize worlds
df['What is your course?'] = df['What is your course?'].str.capitalize()
df['Your current year of Study'] = df['Your current year of Study'].str.capitalize()

# %%
#transfer Yes-No to 1-0
df[['Marital status','What is your course?','Do you have Depression?','Do you have Anxiety?','Do you have Panic attack?','Did you seek any specialist for a treatment?']]=df[['Marital status','What is your course?','Do you have Depression?','Do you have Anxiety?','Do you have Panic attack?','Did you seek any specialist for a treatment?']].replace('Yes',1)
df[['Marital status','What is your course?','Do you have Depression?','Do you have Anxiety?','Do you have Panic attack?','Did you seek any specialist for a treatment?']]=df[['Marital status','What is your course?','Do you have Depression?','Do you have Anxiety?','Do you have Panic attack?','Did you seek any specialist for a treatment?']].replace('No',0)

# %%
df['Your current year of Study']= df['Your current year of Study'].replace('Year 1',1)
df['Your current year of Study']= df['Your current year of Study'].replace('Year 2',2)
df['Your current year of Study']= df['Your current year of Study'].replace('Year 3',3)
df['Your current year of Study']= df['Your current year of Study'].replace('Year 4',4)

# %%
for i in df.columns:
    print(df[i].unique())
# Out:
# [datetime.date(2020, 8, 7) datetime.date(2020, 9, 7)
#  datetime.date(2020, 7, 13) datetime.date(2020, 7, 18)]
# [datetime.time(12, 2) datetime.time(12, 4) datetime.time(12, 5)
#  datetime.time(12, 6) datetime.time(12, 13) datetime.time(12, 31)
#  datetime.time(12, 32) datetime.time(12, 33) datetime.time(12, 35)
#  datetime.time(12, 39) datetime.time(12, 40) datetime.time(12, 41)
#  datetime.time(12, 43) datetime.time(12, 46) datetime.time(12, 52)
#  datetime.time(13, 5) datetime.time(13, 7) datetime.time(13, 12)
#  datetime.time(13, 13) datetime.time(13, 15) datetime.time(13, 17)
#  datetime.time(13, 29) datetime.time(13, 35) datetime.time(13, 41)
#  datetime.time(13, 58) datetime.time(14, 5) datetime.time(14, 27)
#  datetime.time(14, 29) datetime.time(14, 31) datetime.time(14, 41)
#  datetime.time(14, 43) datetime.time(14, 45) datetime.time(14, 47)
#  datetime.time(14, 56) datetime.time(14, 57) datetime.time(14, 58)
#  datetime.time(15, 7) datetime.time(15, 8) datetime.time(15, 9)
# ...

# %%
df.head()
# Out:
#         Dates      Time Choose your gender   Age What is your course?  \
# 0  2020-08-07  12:02:00             Female  18.0          Engineering
# 1  2020-08-07  12:04:00               Male  21.0    Islamic education
# 2  2020-08-07  12:05:00               Male  19.0                   It
# 3  2020-08-07  12:06:00             Female  22.0                 Laws
# 4  2020-08-07  12:13:00               Male  23.0         Mathemathics
#
#    Your current year of Study  What is your CGPA?  Marital status  \
# 0                           1                   3               0
# 1                           2                   3               0
# 2                           1                   3               0
# 3                           3                   3               1
# 4                           4                   3               0
#
#    Do you have Depression?  Do you have Anxiety?  Do you have Panic attack?  \
# ...

# %%
df.to_csv(r'C:\Users\James\Documents\CODE DATA ANALYSIS\module 2\mental_health_clean.csv')

# %%
# Matplotlib
# bar chart
df.groupby(['Age'])['Do you have Depression?'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
# pie
df.groupby(['Age'])['Do you have Depression?'].count().plot.pie()
# Out:
# <AxesSubplot:ylabel='Do you have Depression?'>

# %%
df['What is your course?'].value_counts().plot(kind="bar",figsize=(15,7))
plt.title('Category of study')
# Out:
# Text(0.5, 1.0, 'Category of study')

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['Do you have Depression?', 'Do you have Anxiety?', 'Do you have Panic attack', 'Did you seek any specialist for a treatment?'])
df.plot.box(grid='True')
plt.title('Mental problem of students')
# Out:
# Text(0.5, 1.0, 'Mental problem of students')

# %%
Score =  ['0 - 1.99','2.00 - 2.49','3.00 - 3.49','3.50 - 4.00']
CGPA =  [1, 2, 3, 4]
plt.step(Score,CGPA)
b= plt.xticks(rotation=45)
plt.savefig('CGPA.jpg')
plt.title('CGPA range')
# Out:
# Text(0.5, 1.0, 'CGPA range')

# %%
from matplotlib.pyplot import figure

figure(figsize=(12, 6))
plt.style.use('classic')
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Do you have Depression?'}>,
#         <AxesSubplot:title={'center':'Do you have Anxiety?'}>],
#        [<AxesSubplot:title={'center':'Do you have Panic attack'}>,
#         <AxesSubplot:title={'center':'Did you seek any specialist for a treatment?'}>]],
#       dtype=object)

# %%
count1 = 0
count0 = 0
list=[]
for i in df['Do you have Depression?']: 
    list.append(i)
  


for i in list : 
    if i == 1:
        count1+=1
    else :
        count0+=1


Depression = ['Yes', 'No']

values = [count1, count0]

plt.bar(Depression, values)

plt.title("result of the 'do you have depression' question in the student questionnary")  ;plt.show()
